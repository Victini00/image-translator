# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(
    use_doc_orientation_classify=False, # Disables document orientation classification model via this parameter
    use_doc_unwarping=False, # Disables text image rectification model via this parameter
    use_textline_orientation=False, # Disables text line orientation classification model via this parameter

    text_detection_model_name = "PP-OCRv5_mobile_det", # Text Detection에 모델들 있음. Detection은 괜찮아서 fine-tuning 필요 없어 보임
    
    text_recognition_model_name = "japan_PP-OCRv3_mobile_rec", # Text Recognition에 모델들 있음
)

result = ocr.predict("shirobako.jpg")  

for res in result:  
    res.print()  
    res.save_to_img("output")  
    res.save_to_json("output")
# Out:
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:717: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 3
#       1 from paddleocr import PaddleOCR
# ----> 3 ocr = PaddleOCR(
#       4     use_doc_orientation_classify=False, # Disables document orientation classification model via this parameter
#       5     use_doc_unwarping=False, # Disables text image rectification model via this parameter
#       6     use_textline_orientation=False, # Disables text line orientation classification model via this parameter
#       7
#       8     text_detection_model_name = "PP-OCRv5_mobile_det", # Text Detection에 모델들 있음. Detection은 괜찮아서 fine-tuning 필요 없어 보임
#       9
#      10     text_recognition_model_name = "japan_PP-OCRv3_mobile_rec", # Text Recognition에 모델들 있음
#      11 )
#      13 result = ocr.predict("shirobako.jpg")
#      15 for res in result:
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\ocr.py:163, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, return_word_box, text_rec_input_shape, lang, ocr_version, **kwargs)
#     159         base_params[name] = val
#     161 self._params = params
# --> 163 super().__init__(**base_params)
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\base.py:67, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      63 self._common_args = parse_common_args(
#      64     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      65 )
#      66 self._merged_paddlex_config = self._get_merged_paddlex_config()
# ---> 67 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\base.py:103, in PaddleXPipelineWrapper._create_paddlex_pipeline(self)
#     102 def _create_paddlex_pipeline(self):
# --> 103     kwargs = prepare_common_init_args(None, self._common_args)
#     104     try:
#     105         return create_pipeline(config=self._merged_paddlex_config, **kwargs)
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_common_args.py:63, in prepare_common_init_args(model_name, common_args)
#      61 device = common_args["device"]
#      62 if device is None:
# ---> 63     device = get_default_device()
#      64 device_type, _ = parse_device(device)
#      66 init_kwargs = {}
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddlex\utils\device.py:53, in get_default_device()
#      52 def get_default_device():
# ---> 53     import paddle
#      55     if paddle.device.is_compiled_with_cuda() and paddle.device.cuda.device_count() > 0:
#      56         return constr_device("gpu", [0])
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\__init__.py:753
#     751     err = ctypes.WinError(last_error)
#     752     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 753     raise err
#     754 elif res is not None:
#     755     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\..\nvidia\cublas\bin\cublas64_12.dll" or one of its dependencies.

# %%
from paddleocr import PaddleOCR

ocr = PaddleOCR(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False,
    lang="japan",          # 일본어 설정 (시각화 폰트/레이아웃 활성화)
    ocr_version="PP-OCRv3" # v3 모델 지정
)

result = ocr.predict("shirobako.jpg")  

for res in result:  
    res.print()  
    res.save_to_img("output")  
    res.save_to_json("output")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from paddleocr import PaddleOCR
#       3 ocr = PaddleOCR(
#       4     use_doc_orientation_classify=False,
#       5     use_doc_unwarping=False,
#    (...)
#       8     ocr_version="PP-OCRv3" # v3 모델 지정
#       9 )
#      11 result = ocr.predict("shirobako.jpg")
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\__init__.py:17
#       1 # Copyright (c) 2025 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from paddlex.inference.utils.benchmark import benchmark
# ---> 17 from ._models import (
#      18     ChartParsing,
#      19     DocImgOrientationClassification,
#      20     DocVLM,
#      21     FormulaRecognition,
#      22     LayoutDetection,
#      23     SealTextDetection,
#      24     TableCellsDetection,
#      25     TableClassification,
#      26     TableStructureRecognition,
#      27     TextDetection,
#      28     TextImageUnwarping,
#      29     TextLineOrientationClassification,
#      30     TextRecognition,
#      31 )
#      32 from ._pipelines import (
#      33     DocPreprocessor,
#      34     DocUnderstanding,
#    (...)
#      42     TableRecognitionPipelineV2,
#      43 )
#      44 from ._utils.logging import logger
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_models\__init__.py:15
#       1 # Copyright (c) 2025 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 15 from .chart_parsing import ChartParsing
#      16 from .doc_img_orientation_classification import DocImgOrientationClassification
#      17 from .doc_vlm import DocVLM
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_models\chart_parsing.py:16
#       1 # Copyright (c) 2025 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 from .._utils.cli import add_simple_inference_args
# ---> 16 from ._doc_vlm import (
#      17     BaseDocVLM,
#      18     BaseDocVLMSubcommandExecutor,
#      19 )
#      22 class ChartParsing(BaseDocVLM):
#      23     @property
#      24     def default_model_name(self):
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_models\_doc_vlm.py:21
#      15 import abc
#      17 from .._utils.cli import (
#      18     get_subcommand_args,
#      19     perform_simple_inference,
#      20 )
# ---> 21 from .base import PaddleXPredictorWrapper, PredictorCLISubcommandExecutor
#      22 from paddlex.utils.pipeline_arguments import custom_type
#      25 class BaseDocVLM(PaddleXPredictorWrapper):
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_models\base.py:17
#       1 # Copyright (c) 2025 PaddlePaddle Authors. All Rights Reserved.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
#      15 import abc
# ---> 17 from paddlex import create_predictor
#      18 from paddlex.utils.deps import DependencyError
#      20 from .._abstract import CLISubcommandExecutor
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddlex\__init__.py:41
#      37     if flags.EAGER_INITIALIZATION:
#      38         repo_manager.initialize()
# ---> 41 _initialize()
#      44 from . import version
#      46 __version__ = version.get_pdx_version()
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddlex\__init__.py:38, in _initialize()
#      35 setup_logging()
#      37 if flags.EAGER_INITIALIZATION:
# ---> 38     repo_manager.initialize()
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddlex\repo_manager\core.py:214, in initialize(repo_names)
#     212 """initialize"""
#     213 if _GlobalContext.is_initialized():
# --> 214     raise RuntimeError(
#     215         "PDX has already been initialized. Reinitialization is not supported."
#     216     )
#     218 if repo_names is None:
#     219     try_all = True
#
# RuntimeError: PDX has already been initialized. Reinitialization is not supported.

# %%
# Initialize PaddleOCR instance
from paddleocr import PaddleOCR

ocr = PaddleOCR(
    use_doc_orientation_classify=False,
    use_doc_unwarping=False,
    use_textline_orientation=False)

# Run OCR inference on a sample image 
result = ocr.predict(
    input="./../data/raw/images/shirobako.png")

# Visualize the results and save the JSON results
for res in result:
    res.print()
    res.save_to_img("output")
    res.save_to_json("output")
# Out:
# Checking connectivity to the model hosters, this may take a while. To bypass this check, set `PADDLE_PDX_DISABLE_MODEL_SOURCE_CHECK` to `True`.
# c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\utils\cpp_extension\extension_utils.py:717: UserWarning: No ccache found. Please be aware that recompiling all source files may be required. You can download and install ccache from: https://github.com/ccache/ccache/blob/master/doc/INSTALL.md
#   warnings.warn(warning_message)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 4
#       1 # Initialize PaddleOCR instance
#       2 from paddleocr import PaddleOCR
# ----> 4 ocr = PaddleOCR(
#       5     use_doc_orientation_classify=False,
#       6     use_doc_unwarping=False,
#       7     use_textline_orientation=False)
#       9 # Run OCR inference on a sample image
#      10 result = ocr.predict(
#      11     input="./../data/raw/images/shirobako.png")
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\ocr.py:163, in PaddleOCR.__init__(self, doc_orientation_classify_model_name, doc_orientation_classify_model_dir, doc_unwarping_model_name, doc_unwarping_model_dir, text_detection_model_name, text_detection_model_dir, textline_orientation_model_name, textline_orientation_model_dir, textline_orientation_batch_size, text_recognition_model_name, text_recognition_model_dir, text_recognition_batch_size, use_doc_orientation_classify, use_doc_unwarping, use_textline_orientation, text_det_limit_side_len, text_det_limit_type, text_det_thresh, text_det_box_thresh, text_det_unclip_ratio, text_det_input_shape, text_rec_score_thresh, return_word_box, text_rec_input_shape, lang, ocr_version, **kwargs)
#     159         base_params[name] = val
#     161 self._params = params
# --> 163 super().__init__(**base_params)
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\base.py:67, in PaddleXPipelineWrapper.__init__(self, paddlex_config, **common_args)
#      63 self._common_args = parse_common_args(
#      64     common_args, default_enable_hpi=_DEFAULT_ENABLE_HPI
#      65 )
#      66 self._merged_paddlex_config = self._get_merged_paddlex_config()
# ---> 67 self.paddlex_pipeline = self._create_paddlex_pipeline()
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_pipelines\base.py:103, in PaddleXPipelineWrapper._create_paddlex_pipeline(self)
#     102 def _create_paddlex_pipeline(self):
# --> 103     kwargs = prepare_common_init_args(None, self._common_args)
#     104     try:
#     105         return create_pipeline(config=self._merged_paddlex_config, **kwargs)
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddleocr\_common_args.py:63, in prepare_common_init_args(model_name, common_args)
#      61 device = common_args["device"]
#      62 if device is None:
# ---> 63     device = get_default_device()
#      64 device_type, _ = parse_device(device)
#      66 init_kwargs = {}
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddlex\utils\device.py:53, in get_default_device()
#      52 def get_default_device():
# ---> 53     import paddle
#      55     if paddle.device.is_compiled_with_cuda() and paddle.device.cuda.device_count() > 0:
#      56         return constr_device("gpu", [0])
#
# File c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\__init__.py:753
#     751     err = ctypes.WinError(last_error)
#     752     err.strerror += f' Error loading "{dll}" or one of its dependencies.'
# --> 753     raise err
#     754 elif res is not None:
#     755     is_loaded = True
#
# OSError: [WinError 127] 지정된 프로시저를 찾을 수 없습니다. Error loading "c:\Users\a\anaconda3\envs\project\lib\site-packages\paddle\..\nvidia\cublas\bin\cublas64_12.dll" or one of its dependencies.
